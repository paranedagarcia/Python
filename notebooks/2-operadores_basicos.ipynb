# %% [markdown]
# # Operadores básicos
#
# https://colab.research.google.com/drive/1PBjQ5QWjprbD8ruNbMt2Z_TufHtEViZ7?usp=sharing

# %%
print("--- Ejemplos de Operaciones Aritméticas junio 2026---")

# Definimos dos números para las operaciones
numero1 = 25
numero2 = 8
print(numero1)
# Out:
# --- Ejemplos de Operaciones Aritméticas junio 2026---
# 25

# %%
print(f"Números: {numero1} y {numero2} en curso python")
# Out:
# Números: 25 y 8 en curso python

# %%
# Suma
resultado_suma = numero1 + numero2
print(f"Suma de {numero1} y {numero2}: {resultado_suma}")
# Out:
# Suma de 25 y 8: 33

# %%
# Resta
resultado_resta = numero1 - numero2
print(f"Resta de {numero1} y {numero2}: {resultado_resta}")
# Out:
# Resta de 25 y 8: 17

# %%
# Multiplicación
resultado_multiplicacion = numero1 * numero2
print(f"Multiplicación de {numero1} y {numero2}: {resultado_multiplicacion}")
# Out:
# Multiplicación de 25 y 8: 200

# %%
# División (siempre devuelve un flotante)
resultado_division = numero1 / numero2
print(f"División de {numero1} y {numero2}: {resultado_division}") # 20 / 7 = 2.857...
# Out:
# División de 25 y 8: 3.125

# %%
# División Entera (descarta la parte decimal)
resultado_division_entera = numero1 // numero2
print(f"División Entera de {numero1} y {numero2}: {resultado_division_entera}") # 20 // 7 = 2
# Out:
# División Entera de 25 y 8: 3

# %%
# Módulo (resto de la división)
resultado_modulo = numero1 % numero2
print(f"Módulo de {numero1} y {numero2}: {resultado_modulo}") # 20 % 7 = 6 (7 cabe 2 veces en 20, sobran 6)
# Out:
# Módulo de 25 y 8: 1

# %%
# Potencia (numero1 elevado a la potencia de numero2)
resultado_potencia = numero1 ** 2 # 20 elevado a la 2
print(f"Potencia de {numero1} al cuadrado: {resultado_potencia}")
# Out:
# Potencia de 25 al cuadrado: 625

# %%
# potencia numero2 elevado al cubo
# sentencia al cubo
# imprimir el resultado
resultado_potencia_cubo = numero2 ** 3
print(f"Potencia de {numero2} al cubo: {resultado_potencia_cubo} cubo")
# Out:
# Potencia de 8 al cubo: 512 cubo

# %%
"""
multiplicar el cuadrado del numero 1  por el cubo del numero 2 y mostrar el resultado
"""

# %%
resultado = resultado_potencia * resultado_potencia_cubo
print(f"Resultado de el cuadrado de {resultado_potencia} por el cubo de {resultado_potencia_cubo} es: {resultado}")
# Out:
# Resultado de el cuadrado de 625 por el cubo de 512 es: 320000

# %% [markdown]
# ### Jerarquía de operaciones

# %%
# Jerarquía PEMDAS
# P: Parentesis
# E: exponenciacion
# M: multiplicacion
# D: division
# A: Adicion
# S: Sustracción
(2 + 3) * (5 + 5)

# %% [markdown]
# ### Operaciones lógicas

# %%
print("--- Ejemplos de Operaciones Lógicas ---")

# Variables booleanas para demostración
es_soleado = True
es_fin_de_semana = False
hay_oferta = True
edad = 25
# Out:
# --- Ejemplos de Operaciones Lógicas ---

# %%
# Operador 'and' (Y lógico)
# Devuelve True si ambas condiciones son True
print(f"¿Es soleado Y es fin de semana? {es_soleado and es_fin_de_semana}")
# Out:
# ¿Es soleado Y es fin de semana? False

# %%
# Operador 'or' (O lógico)
# Devuelve True si al menos una de las condiciones es True
print(f"¿Es soleado O hay oferta? {es_soleado or hay_oferta}") # True or True = True

print(f"¿Es fin de semana O hay oferta? {es_fin_de_semana or hay_oferta}")
# Out:
# ¿Es soleado O hay oferta? True
# ¿Es fin de semana O hay oferta? True

# %%
# Operador 'not' (Negación lógica)
# Invierte el valor booleano (True se vuelve False, False se vuelve True)
print(f"¿NO es soleado? {not es_soleado}") 
print(f"¿NO es fin de semana? {not es_fin_de_semana}")
# Out:
# ¿NO es soleado? False
# ¿NO es fin de semana? True

# %%
# Combinación de operadores lógicos y de comparación
# Una persona es apta si tiene más de 18 Y hay oferta
es_apto = (edad > 18) and hay_oferta
es_apto
# Out:
# True

# %%
# Una persona puede ir a la playa si es soleado O si hay oferta (para comprar algo)
puede_ir_playa = es_soleado or hay_oferta
print(f"¿Puede ir a la playa (es soleado o hay oferta)? {puede_ir_playa}")
# Out:
# ¿Puede ir a la playa (es soleado o hay oferta)? True

# %%
print("--- Combinación de Operaciones Aritméticas y Lógicas en una Función ---")

def analizar_numero(numero):
    # Operación aritmética: duplicar el número
    numero_duplicado = numero * 2
    print(f"  Número original: {numero}")
    print(f"  Número duplicado: {numero_duplicado}")

    # Operaciones lógicas y aritméticas para determinar propiedades
    es_par = (numero % 2 == 0) # true o false, comprueba si el número es par usando el módulo y comparación
    es_mayor_que_diez = (numero > 10) # true o False # Comprueba si es mayor que 10 usando comparación
    es_duplicado_interesante = (numero_duplicado > 20) and (not es_par) # true Lógica con el duplicado

    # Usamos operaciones lógicas para decidir el mensaje de retorno
    if es_par and es_mayor_que_diez:
        return f"El número {numero} es PAR y MAYOR que 10. Su duplicado es {numero_duplicado}."
    elif not es_par and es_duplicado_interesante:
        return f"El número {numero} es IMPAR y su duplicado ({numero_duplicado}) es INTERESANTE (mayor que 20)."
    elif es_par:
        return f"El número {numero} es PAR pero no mayor que 10. Su duplicado es {numero_duplicado}."
    else: # Si es impar y su duplicado no es interesante
        return f"El número {numero} es IMPAR, y su duplicado ({numero_duplicado}) no es mayor que 20."


# Demostración de la función con varios números
print("\n--- Ejemplos de uso de la función ---")
print(analizar_numero(12)) # Par y mayor que 10
print(analizar_numero(7))  # Impar, duplicado 14 (no > 20)
print(analizar_numero(15)) # Impar, duplicado 30 ( > 20)
print(analizar_numero(6))  # Par y no mayor que 10
# Out:
# --- Combinación de Operaciones Aritméticas y Lógicas en una Función ---
#
# --- Ejemplos de uso de la función ---
#   Número original: 12
#   Número duplicado: 24
# El número 12 es PAR y MAYOR que 10. Su duplicado es 24.
#   Número original: 7
#   Número duplicado: 14
# El número 7 es IMPAR, y su duplicado (14) no es mayor que 20.
#   Número original: 15
#   Número duplicado: 30
# El número 15 es IMPAR y su duplicado (30) es INTERESANTE (mayor que 20).
#   Número original: 6
#   Número duplicado: 12
# El número 6 es PAR pero no mayor que 10. Su duplicado es 12.

# %% [markdown]
# https://teams.live.com/meet/935038194282?p=NtG0bdRjKwF2RsNrmP
