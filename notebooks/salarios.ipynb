# %% [markdown]
# # Guía de ejercicios Pandas DataFrame

# %% [markdown]
# En esta guía utilizaremos el siguiente dataset [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) extraido desde Kaggle (kaggle.com). Complete cada uno de los ejercicios:

# %% [markdown]
# #### 1. Importe la librería pandas con el alias pd

# %%
import pandas as pd

# %% [markdown]
# #### 2. Lea el siguiente archivo https://patricioaraneda.cl/public/Salaries.csv y almacénelo en una variable (nómbrela "sal")
# Asegúrese que cuenta con el archivo y se encuentra en la misma carpeta que este notebook.

# %%
data = pd.read_csv('https://patricioaraneda.cl/public/Salaries.csv')

# %% [markdown]
# #### 3. Despliegue los primeros 4 registros de los datos

# %%
data.sample(10)
# Out:
#             Id        EmployeeName                         JobTitle  \
# 81652    81653    Roselle D Ferrer   Senior Water Service Inspector
# 83663    83664  Jose G Calvo-Perez                   Police Officer
# 39904    39905     Robert Dufresne                 Transit Operator
# 13010    13011         CONNIE CHAN  ADMINISTRATIVE SERVICES MANAGER
# 29020    29021       HUI XIAN ZHAO                           PORTER
# 134015  134016   Clarence M Dalton                        Custodian
# 57145    57146         Kamson Chan                 Transit Operator
# 116493  116494     James I Whipple        Senior Building Inspector
# 104789  104790        Cula A Clark           Patient Care Assistant
# 118368  118369     Carolyn A Welch        Pr Administrative Analyst
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# 81652   101723.47      2710.97   8932.79  34363.87  113367.23
# 83663    91917.39      7274.51   3613.22  32389.62  102805.12
# 39904    71251.23     56238.12   9401.86  44850.59  136891.21
# 13010    84783.37         0.00      0.00       NaN   84783.37
# 29020    21644.50         0.00    642.95       NaN   22287.45
# 134015   54703.00      3185.40    624.00  26651.90   58512.40
# 57145    65380.02      2344.82    749.02  23049.59   68473.86
# 116493  120350.05      1076.70   6017.55  40854.39  127444.30
# 104789   14726.79         0.00    376.25      0.00   15103.04
# 118368  114317.03         0.00      0.00  39423.56  114317.03
#
#         TotalPayBenefits  Year  Notes         Agency  Status      Taxes
# 81652          147731.10  2013    NaN  San Francisco     NaN  10172.347
# 83663          135194.74  2013    NaN  San Francisco     NaN   9191.739
# 39904          181741.80  2012    NaN  San Francisco     NaN   7125.123
# 13010           84783.37  2011    NaN  San Francisco     NaN   8478.337
# 29020           22287.45  2011    NaN  San Francisco     NaN   2164.450
# 134015          85164.30  2014    NaN  San Francisco     NaN   5470.300
# 57145           91523.45  2012    NaN  San Francisco     NaN   6538.002
# 116493         168298.69  2014    NaN  San Francisco     NaN  12035.005
# 104789          15103.04  2013    NaN  San Francisco     NaN   1472.679
# 118368         153740.59  2014    NaN  San Francisco     NaN  11431.703

# %%
data.head(4)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN

# %% [markdown]
# #### 4. Despliegue los últimos 2 registros del set de datos

# %%
data.tail(2)
# Out:
#             Id  EmployeeName                    JobTitle  BasePay  \
# 148652  148653  Not provided                Not provided      NaN
# 148653  148654     Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148652    NaN  San Francisco     NaN
# 148653    NaN  San Francisco     NaN

# %% [markdown]
# #### 5. Utilice el método .info() para ver cuántos registros tiene el set de datos

# %% [markdown]
# #### 6. Utilice el método .describe() para obtener estadísticas rápidas del set de datos

# %% [markdown]
# #### 7. ¿Cuál es el monto del sueldo base más alto? (BasePay)

# %%
data['BasePay'].max()
# Out:
# np.float64(319275.01)

# %% [markdown]
# #### 8. ¿Cuál es la mediana del sueldo base?

# %%
data['BasePay'].median()
# Out:
# np.float64(65007.45)

# %% [markdown]
# #### 9. ¿Cuál es la media del sueldo base?

# %%
data['BasePay'].mean()
# Out:
# np.float64(66325.44884048769)

# %% [markdown]
# #### 10. ¿Cuánto fue el monto de sueldo base (BasePay) más alto del año 2013?

# %%
data[data['Year'] == 2013]['BasePay'].max()
# Out:
# np.float64(319275.01)

# %% [markdown]
# #### 11. ¿A cuántas personas se les paga tiempo extra? (OvertimePay)

# %%
# la condicion evalua true o false, y luego sum() suma los valores true, que son equivalentes a 1
(data['OvertimePay'] > 0).sum()
# Out:
# np.int64(71328)

# %%
(data['OvertimePay'] > 0).sum()

# %% [markdown]
# #### 12. ¿Cuál es el cargo de JOSEPH DRISCOLL?
# **Nota**: Use mayúsculas (también hay un Joseph Driscoll con minúsculas)

# %%
data[data['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle'].values[0]
# Out:
# 'CAPTAIN, FIRE SUPPRESSION'

# %% [markdown]
# #### 13. ¿Cuál es el sueldo total de JOSEPH DRISCOLL incluyendo beneficios?

# %%
data[data['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits'].values[0]
# Out:
# np.float64(270324.91)

# %% [markdown]
# #### 14. ¿Cuál es el nombre de la persona mejor pagada? (beneficios incluidos)

# %%
data.loc[data['TotalPayBenefits'].idxmax(), 'EmployeeName']
# Out:
# 'NATHANIEL FORD'

# %% [markdown]
# #### 15. ¿Cuál es el nombre de persona peor pagada (beneficios incluidos)?

# %%
data.loc[data['TotalPayBenefits'].idxmin(), 'EmployeeName']
# Out:
# 'Joe Lopez'

# %% [markdown]
# #### 16. Agregue una columna que se llame 'Taxes' y que corresponda al 10% del sueldo base

# %%
data['Taxes'] = data['BasePay'] * 0.10

# %% [markdown]
# #### 17. ¿Cuánto fue la recaudación de impuestos en el año 2013?

# %%
data[data['Year'] == 2013]['Taxes'].sum()
# Out:
# np.float64(257638074.80400002)

# %% [markdown]
# #### 18. Desafío: calcule el promedio del 10% de sueldos más altos (BasePay)

# %%
data['BasePay'].dropna().nlargest(int(len(data) * 0.10)).mean()
# Out:
# np.float64(145160.43789640092)

# %% [markdown]
# #### 19. Calcule el promedio del 10% de sueldos más bajos (BasePay)

# %%
data['BasePay'].dropna().nsmallest(int(len(data) * 0.10)).mean()
# Out:
# np.float64(2742.6652929700645)
